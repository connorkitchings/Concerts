# %%
import pandas as pd
import os
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# %%
pd.set_option('display.max_columns', None)

# %%
today = datetime.today().strftime('%Y-%m-%d')
todayminus1year = (datetime.now() - relativedelta(years=1)).strftime('%Y-%m-%d')
todayminus2year = (datetime.now() - relativedelta(years=2)).strftime('%Y-%m-%d')

# %%
try:
    script_dir = os.path.dirname(os.path.abspath(__file__))
except NameError:
    script_dir = os.getcwd()
base_dir = os.path.dirname(script_dir)
data_dir = os.path.join(base_dir, "Data", "Widespread_Panic")

# %%
songdata = pd.read_csv(os.path.join(data_dir, "songdata.csv"))
showdata = pd.read_csv(os.path.join(data_dir, "showdata.csv"))
setlistdata = pd.read_csv(os.path.join(data_dir, "setlistdata.csv"))

# %%
showdata['date'] = pd.to_datetime(showdata['date'], format='%m/%d/%y', errors='coerce')
last_show = showdata['show_index_overall'].max()
showdata.tail()
# Out:
#            date  year  month  day   weekday   date_ec  \
# 3210 2024-05-25  2024      5   25  Saturday  05/25/24
# 3211 2024-06-20  2024      6   20  Thursday  06/20/24
# 3212 2024-06-21  2024      6   21    Friday  06/21/24
# 3213 2024-06-22  2024      6   22  Saturday  06/22/24
# 3214 2024-06-23  2024      6   23    Sunday  06/23/24
#
#                                                venue      city state  \
# 3210  RADIANE AMPHITHEATER AT MEMPHIS BOTANIC GARDEN   MEMPHIS    TN
# 3211                      EMPOWER FIELD AT MILE HIGH    DENVER    CO
# 3212                                       RED ROCKS  MORRISON    CO
# 3213                                       RED ROCKS  MORRISON    CO
# 3214                                       RED ROCKS  MORRISON    CO
#
#       show_index_overall  show_index_withinyear  run_index  \
# 3210                3211                     13       2485
# 3211                3212                     14       2486
# 3212                3213                     15       2487
# 3213                3214                     16       2487
# 3214                3215                     17       2487
#
#                                              venue_full  \
# 3210  RADIANE AMPHITHEATER AT MEMPHIS BOTANIC GARDEN...
# 3211             EMPOWER FIELD AT MILE HIGH, DENVER, CO
# 3212                            RED ROCKS, MORRISON, CO
# 3213                            RED ROCKS, MORRISON, CO
# 3214                            RED ROCKS, MORRISON, CO
#
#                                                    link
# 3210  http://everydaycompanion.com/setlists/20240525...
# 3211  http://everydaycompanion.com/setlists/20240620...
# 3212  http://everydaycompanion.com/setlists/20240621...
# 3213  http://everydaycompanion.com/setlists/20240622...
# 3214  http://everydaycompanion.com/setlists/20240623...

# %%
songdata.head()
# Out:
#                   song    code       ftp       ltp  times_played  aka
# 0                  ???     ???  06/06/87  04/23/93             3  NaN
# 1       One Kind Favor  1FAVOR  07/18/97  07/24/22            54  NaN
# 2        One Arm Steve  1STEVE  04/18/98  06/21/24           309  NaN
# 3          Second Skin  2NDSKN  03/24/05  04/15/24           165  NaN
# 4  Tonight's the Night  2NNGHT  05/14/03  04/26/05             9  NaN

# %%
setlistdata.tail(5)
# Out:
#                     song_name set  song_index_set  song_index_show  into  \
# 62115             BLUE INDIAN  2:              10               20     1
# 62116  LAWYERS GUNS AND MONEY  2:              11               21     0
# 62117          LIFE AS A TREE  E:               1               22     0
# 62118                 PIGEONS  E:               2               23     0
# 62119                POSTCARD  E:               3               24     0
#
#        song_notes_key  notes_id  \
# 62115             NaN       0.0
# 62116             NaN       0.0
# 62117             NaN       0.0
# 62118             NaN       0.0
# 62119             NaN       0.0
#
#                                                     link song_note_detail
# 62115  http://everydaycompanion.com/setlists/20240623...              NaN
# 62116  http://everydaycompanion.com/setlists/20240623...              NaN
# 62117  http://everydaycompanion.com/setlists/20240623...              NaN
# 62118  http://everydaycompanion.com/setlists/20240623...              NaN
# 62119  http://everydaycompanion.com/setlists/20240623...              NaN

# %%
showdata.head(1)
# Out:
#   date  year  month  day weekday   date_ec                    venue    city  \
# 0  NaT  1985      0    0     NaN  ??/??/85  A-FRAME, WEYMANDA COURT  ATHENS
#
#   state  show_index_overall  show_index_withinyear  run_index  \
# 0    GA                   1                      1          1
#
#                             venue_full  \
# 0  A-FRAME, WEYMANDA COURT, ATHENS, GA
#
#                                                 link
# 0  http://everydaycompanion.com/setlists/19850000...

# %%
songs_and_shows = pd.merge(setlistdata, showdata, on='link', how='left').sort_values(['song_name','show_index_overall']).reset_index(drop=True)
songs_and_shows['gap'] = songs_and_shows.groupby('song_name')['show_index_overall'].diff()
songs_and_shows.loc[songs_and_shows.groupby('song_name').head(1).index, 'gap'] = None 
songs_and_shows.head()
# Out:
#                           song_name set  song_index_set  song_index_show  \
# 0           (DON'T FEAR) THE REAPER  2:              11               19
# 1      (DON'T GO BACK TO) ROCKVILLE  2:              12               21
# 2  (SITTIN' ON) THE DOCK OF THE BAY  E:               2               21
# 3  (SITTIN' ON) THE DOCK OF THE BAY  1:               1                1
# 4  (SITTIN' ON) THE DOCK OF THE BAY  E:               1               21
#
#    into  song_notes_key  notes_id  \
# 0     1             NaN       NaN
# 1     0             NaN       NaN
# 2     1             NaN       0.0
# 3     0             NaN       NaN
# 4     0             NaN       NaN
#
#                                                 link  \
# 0  http://everydaycompanion.com/setlists/20181028...
# 1  http://everydaycompanion.com/setlists/20091230...
# 2  http://everydaycompanion.com/setlists/20051229...
# 3  http://everydaycompanion.com/setlists/20051231...
# 4  http://everydaycompanion.com/setlists/20060708...
#
#                                     song_note_detail       date  year  month  \
# 0                        with Ben Draper on cowbell  2018-10-28  2018     10
# 1   with Mike Mills on vocals, Randall Bramblett ... 2009-12-30  2009     12
# 2                                                NaN 2005-12-29  2005     12
# 3                                                NaN 2005-12-31  2005     12
# 4             with John Keane on guitar/pedal steel  2006-07-08  2006      7
#
#    day    weekday   date_ec          venue       city state  \
# 0   28     Sunday  10/28/18   PARK THEATER  LAS VEGAS    NV
# 1   30  Wednesday  12/30/09  PHILIPS ARENA    ATLANTA    GA
# 2   29   Thursday  12/29/05       THE ROXY    ATLANTA    GA
# 3   31   Saturday  12/31/05  PHILIPS ARENA    ATLANTA    GA
# 4    8   Saturday  07/08/06  GREEK THEATRE   BERKELEY    CA
#
#    show_index_overall  show_index_withinyear  run_index  \
# 0                3027                     32       2423
# 1                2490                     53       2082
# 2                2185                    101       1877
# 3                2187                    103       1878
# 4                2206                     19       1888
#
#                     venue_full   gap
# 0  PARK THEATER, LAS VEGAS, NV   NaN
# 1   PHILIPS ARENA, ATLANTA, GA   NaN
# 2        THE ROXY, ATLANTA, GA   NaN
# 3   PHILIPS ARENA, ATLANTA, GA   2.0
# 4  GREEK THEATRE, BERKELEY, CA  19.0

# %%
my_song_data = (songs_and_shows.groupby(['song_name'])
                .agg({
                    'show_index_overall': ['count', 'min', 'max'],
                    'gap': ['min', 'max', 'mean', 'median', 'std']
                })
                .reset_index()
                .round(2)
)
my_song_data.columns = ['_'.join(col).strip() for col in my_song_data.columns.values]
# Rename columns for easier access
my_song_data = my_song_data.rename(columns={
    'song_name_': 'song_name', 
    'show_index_overall_count': 'times_played_total', 
    'show_index_overall_min': 'debut', 
    'show_index_overall_max': 'last_played', 
    'gap_min': 'min_gap', 
    'gap_max': 'max_gap', 
    'gap_mean': 'avg_gap',
    'gap_median': 'med_gap',  
    'gap_std': 'std_gap'
})

my_song_data['current_gap'] = last_show - my_song_data['last_played']

my_song_data = (my_song_data
                .merge(showdata[['show_index_overall', 'date']], left_on='debut', right_on='show_index_overall', how='left')
                .rename(columns={'date': 'debut_date'}).drop(columns=['show_index_overall', 'debut'])
                .merge(showdata[['show_index_overall', 'date']], left_on='last_played', right_on='show_index_overall', how='left')
                .rename(columns={'date': 'ltp_date'}).drop(columns=['show_index_overall', 'last_played'])
)[['song_name', 'times_played_total','debut_date','ltp_date','current_gap','avg_gap', 'med_gap', 'std_gap']]

my_song_data['gap_zscore'] = (my_song_data['current_gap'] - my_song_data['avg_gap']) / my_song_data['std_gap']
my_song_data['debut_date'] = pd.to_datetime(my_song_data['debut_date']).dt.strftime('%m/%d/%y')
my_song_data['ltp_date'] = pd.to_datetime(my_song_data['ltp_date']).dt.strftime('%m/%d/%y')

my_song_data.head()
# Out:
#                           song_name  times_played_total debut_date  ltp_date  \
# 0           (DON'T FEAR) THE REAPER                   1   10/28/18  10/28/18
# 1      (DON'T GO BACK TO) ROCKVILLE                   1   12/30/09  12/30/09
# 2  (SITTIN' ON) THE DOCK OF THE BAY                   4   12/29/05  03/29/14
# 3                             1 X 1                 147   03/23/95  05/27/23
# 4        A HARD RAIN'S A-GONNA FALL                  20   12/31/15  03/22/24
#
#    current_gap  avg_gap  med_gap  std_gap  gap_zscore
# 0          188      NaN      NaN      NaN         NaN
# 1          725      NaN      NaN      NaN         NaN
# 2          454   192.00     19.0   314.48    0.833121
# 3           37    13.71     10.0    15.18    1.534256
# 4           13    16.68     15.0    13.22   -0.278366

# %%
my_song_data['ltp_date'] = pd.to_datetime(my_song_data['ltp_date'], format='%m/%d/%y', errors='coerce')
three_years_ago = datetime.today() - timedelta(days=3*365)
ck_plus = (my_song_data[(my_song_data['times_played_total'] > 10)&(my_song_data['ltp_date'] > three_years_ago)].copy()
           .sort_values(by='gap_zscore', ascending=False).reset_index(drop=True).drop(columns=['debut_date', 'std_gap','gap_zscore'])
)
ck_plus['current_minus_avg'] = ck_plus['current_gap'] - ck_plus['avg_gap']
ck_plus['current_minus_med'] = ck_plus['current_gap'] - ck_plus['med_gap']

ck_plus.head()
# Out:
#              song_name  times_played_total   ltp_date  current_gap  avg_gap  \
# 0  WEIGHT OF THE WORLD                 588 2022-10-23           64     4.43
# 1            SELL SELL                  76 2022-09-18           69     6.40
# 2         STEVEN'S CAT                  52 2022-09-16           71     6.08
# 3      IT AIN'T NO USE                 365 2022-08-11           77     7.52
# 4   YOU SHOULD BE GLAD                 172 2023-02-09           54     6.26
#
#    med_gap  current_minus_avg  current_minus_med
# 0      3.0              59.57               61.0
# 1      5.0              62.60               64.0
# 2      4.0              64.92               67.0
# 3      5.0              69.48               72.0
# 4      5.0              47.74               49.0

# %%
jojos_notebook_data = (songs_and_shows[(songs_and_shows['date'] > todayminus2year)]).reset_index(drop=True)[['song_name', 'show_index_overall', 'date','gap']]

jojos_notebook = (jojos_notebook_data.groupby(['song_name']).agg({
    'show_index_overall': ['count', 'max'],
    'gap': ['min', 'max', 'mean', 'median', 'std']})
                  .reset_index().round(2)
)

jojos_notebook.columns = ['_'.join(col).strip() for col in jojos_notebook.columns.values]

# Rename columns for easier access
jojos_notebook = jojos_notebook.rename(columns={
    'song_name_': 'song_name', 
    'show_index_overall_count': 'times_played_in_last_year', 
    'show_index_overall_max': 'last_played', 
    'gap_min': 'min_gap', 
    'gap_max': 'max_gap', 
    'gap_mean': 'avg_gap',
    'gap_median': 'med_gap',  
    'gap_std': 'std_gap'
})

jojos_notebook['current_gap'] = last_show - jojos_notebook['last_played']

jojos_notebook = (jojos_notebook
                .merge(showdata[['show_index_overall', 'date']], left_on='last_played', right_on='show_index_overall', how='left')
                .rename(columns={'date': 'ltp_date'}).drop(columns=['show_index_overall', 'last_played'])
)[['song_name', 'times_played_in_last_year','ltp_date','current_gap','avg_gap', 'med_gap']]

jojos_notebook = (jojos_notebook[(jojos_notebook['current_gap'] > 3)].sort_values(by='times_played_in_last_year', ascending=False)
                  .reset_index(drop=True)
)

jojos_notebook.head()
# Out:
#             song_name  times_played_in_last_year   ltp_date  current_gap  \
# 0  HENRY PARSONS DIED                         14 2024-05-24            5
# 1                ROCK                         14 2024-05-25            4
# 2           WONDERING                         13 2024-04-25            6
# 3               DISCO                         13 2024-05-25            4
# 4               DINER                         12 2024-05-25            4
#
#    avg_gap  med_gap
# 0     3.71      4.0
# 1     3.79      5.0
# 2     4.15      5.0
# 3     3.92      4.0
# 4     4.33      4.5

# %%
# Saving all datasets to CSV
try:
    script_dir = os.path.dirname(os.path.abspath(__file__))
except NameError:
    script_dir = os.getcwd()
base_dir = os.path.dirname(script_dir)
save_path = os.path.join(base_dir, "Data", "Widespread_Panic")
ck_plus.to_csv(os.path.join(save_path, "ckplus_wsp.csv"), index=False)
jojos_notebook.to_csv(os.path.join(save_path, "jojos_notebook.csv"), index=False)
