# %%
import pandas as pd
import os
from datetime import datetime, timedelta, date
from dateutil.relativedelta import relativedelta

# %%
pd.set_option('display.max_columns', None)

# %%
today = datetime.today().strftime('%Y-%m-%d')
todayminus1year = (datetime.now() - relativedelta(years=1)).strftime('%Y-%m-%d')
todayminus2year = (datetime.now() - relativedelta(years=2)).strftime('%Y-%m-%d')

# %%
try:
    script_dir = os.path.dirname(os.path.abspath(__file__))
except NameError:
    script_dir = os.getcwd()
base_dir = os.path.dirname(script_dir)
data_dir = os.path.join(base_dir, "Data", "WSP", "From Web")

# %%
songdata = pd.read_csv(os.path.join(data_dir, "songdata.csv"))
songdata['song'] = songdata['song'].str.title()
showdata = pd.read_csv(os.path.join(data_dir, "showdata.csv"))

# %%
setlistdata = pd.read_csv(os.path.join(data_dir, "setlistdata.csv")).dropna(subset='song_name')
setlistdata['song_name'] = setlistdata['song_name'].str.title()
setlistdata = setlistdata.sort_values(by=['link', 'song_name', 'song_index_show']).reset_index(drop=True)
setlistdata['isreprise'] = setlistdata.groupby(['link', 'song_name']).cumcount().astype(int)
setlistdata = setlistdata[setlistdata['isreprise']==0].sort_values(by=['link', 'song_index_show']).reset_index(drop=True)

# %%
showdata['date'] = pd.to_datetime(showdata['date'], format='%m/%d/%y', errors='coerce')
last_show = showdata['show_index_overall'].max()
print(last_show)
showdata.tail()
# Out:
# 3215
#            date  year  month  day   weekday   date_ec  \
# 3210 2024-05-25  2024      5   25  Saturday  05/25/24
# 3211 2024-06-20  2024      6   20  Thursday  06/20/24
# 3212 2024-06-21  2024      6   21    Friday  06/21/24
# 3213 2024-06-22  2024      6   22  Saturday  06/22/24
# 3214 2024-06-23  2024      6   23    Sunday  06/23/24
#
#                                                venue      city state  \
# 3210  RADIANE AMPHITHEATER AT MEMPHIS BOTANIC GARDEN   MEMPHIS    TN
# 3211                      EMPOWER FIELD AT MILE HIGH    DENVER    CO
# 3212                                       RED ROCKS  MORRISON    CO
# 3213                                       RED ROCKS  MORRISON    CO
# 3214                                       RED ROCKS  MORRISON    CO
#
#       show_index_overall  show_index_withinyear  run_index  \
# 3210                3211                     13       2485
# 3211                3212                     14       2486
# 3212                3213                     15       2487
# 3213                3214                     16       2487
# 3214                3215                     17       2487
#
#                                              venue_full  \
# 3210  RADIANE AMPHITHEATER AT MEMPHIS BOTANIC GARDEN...
# 3211             EMPOWER FIELD AT MILE HIGH, DENVER, CO
# 3212                            RED ROCKS, MORRISON, CO
# 3213                            RED ROCKS, MORRISON, CO
# 3214                            RED ROCKS, MORRISON, CO
#
#                                                    link
# 3210  http://www.everydaycompanion.com/setlists/2024...
# 3211  http://www.everydaycompanion.com/setlists/2024...
# 3212  http://www.everydaycompanion.com/setlists/2024...
# 3213  http://www.everydaycompanion.com/setlists/2024...
# 3214  http://www.everydaycompanion.com/setlists/2024...

# %%
songdata.head()
# Out:
#                   song    code       ftp       ltp  times_played  aka
# 0                  ???     ???  06/06/87  04/23/93             3  NaN
# 1       One Kind Favor  1FAVOR  07/18/97  07/24/22            54  NaN
# 2        One Arm Steve  1STEVE  04/18/98  06/21/24           309  NaN
# 3          Second Skin  2NDSKN  03/24/05  04/15/24           165  NaN
# 4  Tonight'S The Night  2NNGHT  05/14/03  04/26/05             9  NaN

# %%
setlistdata.tail(5)
# Out:
#                     song_name set  song_index_set  song_index_show  into  \
# 59842             Blue Indian  2:              10               20     1
# 59843  Lawyers Guns And Money  2:              11               21     0
# 59844          Life As A Tree  E:               1               22     0
# 59845                 Pigeons  E:               2               23     0
# 59846                Postcard  E:               3               24     0
#
#        song_notes_key  notes_id  \
# 59842             NaN       0.0
# 59843             NaN       0.0
# 59844             NaN       0.0
# 59845             NaN       0.0
# 59846             NaN       0.0
#
#                                                     link song_note_detail  \
# 59842  http://www.everydaycompanion.com/setlists/2024...              NaN
# 59843  http://www.everydaycompanion.com/setlists/2024...              NaN
# 59844  http://www.everydaycompanion.com/setlists/2024...              NaN
# 59845  http://www.everydaycompanion.com/setlists/2024...              NaN
# 59846  http://www.everydaycompanion.com/setlists/2024...              NaN
#
#        isreprise
# 59842          0
# 59843          0
# 59844          0
# 59845          0
# 59846          0

# %%
setlist_by_song = (pd.merge(setlistdata, 
                                   showdata, 
                                   on='link', 
                                   how='left')
                           .sort_values(['song_name','show_index_overall'])
                           .reset_index(drop=True))
        
setlist_by_song['gap'] = setlist_by_song.groupby('song_name')['show_index_overall'].diff()
setlist_by_song.loc[setlist_by_song.groupby('song_name').head(1).index, 'gap'] = None 
setlist_by_song.head()
# Out:
#                           song_name set  song_index_set  song_index_show  \
# 0           (Don'T Fear) The Reaper  2:              11               19
# 1      (Don'T Go Back To) Rockville  2:              12               21
# 2  (Sittin' On) The Dock Of The Bay  E:               2               21
# 3  (Sittin' On) The Dock Of The Bay  1:               1                1
# 4  (Sittin' On) The Dock Of The Bay  E:               1               21
#
#    into  song_notes_key  notes_id  \
# 0     1             NaN       NaN
# 1     0             NaN       NaN
# 2     1             NaN       0.0
# 3     0             NaN       NaN
# 4     0             NaN       NaN
#
#                                                 link  \
# 0  http://www.everydaycompanion.com/setlists/2018...
# 1  http://www.everydaycompanion.com/setlists/2009...
# 2  http://www.everydaycompanion.com/setlists/2005...
# 3  http://www.everydaycompanion.com/setlists/2005...
# 4  http://www.everydaycompanion.com/setlists/2006...
#
#                                     song_note_detail  isreprise      date  \
# 0                        with Ben Draper on cowbell           0  10/28/18
# 1   with Mike Mills on vocals, Randall Bramblett ...          0  12/30/09
# 2                                                NaN          0  12/29/05
# 3                                                NaN          0  12/31/05
# 4             with John Keane on guitar/pedal steel           0  07/08/06
#
#    year  month  day    weekday   date_ec          venue       city state  \
# 0  2018     10   28     Sunday  10/28/18   PARK THEATER  LAS VEGAS    NV
# 1  2009     12   30  Wednesday  12/30/09  PHILIPS ARENA    ATLANTA    GA
# 2  2005     12   29   Thursday  12/29/05       THE ROXY    ATLANTA    GA
# 3  2005     12   31   Saturday  12/31/05  PHILIPS ARENA    ATLANTA    GA
# 4  2006      7    8   Saturday  07/08/06  GREEK THEATRE   BERKELEY    CA
#
#    show_index_overall  show_index_withinyear  run_index  \
# 0                3027                     32       2423
# 1                2490                     53       2082
# 2                2185                    101       1877
# 3                2187                    103       1878
# 4                2206                     19       1888
#
#                     venue_full   gap
# 0  PARK THEATER, LAS VEGAS, NV   NaN
# 1   PHILIPS ARENA, ATLANTA, GA   NaN
# 2        THE ROXY, ATLANTA, GA   NaN
# 3   PHILIPS ARENA, ATLANTA, GA   2.0
# 4  GREEK THEATRE, BERKELEY, CA  19.0

# %%
songdata.head(5)
# Out:
#                   song    code       ftp       ltp  times_played  aka
# 0                  ???     ???  06/06/87  04/23/93             3  NaN
# 1       One Kind Favor  1FAVOR  07/18/97  07/24/22            54  NaN
# 2        One Arm Steve  1STEVE  04/18/98  06/21/24           309  NaN
# 3          Second Skin  2NDSKN  03/24/05  04/15/24           165  NaN
# 4  Tonight's the Night  2NNGHT  05/14/03  04/26/05             9  NaN

# %%
my_song_data = (setlist_by_song.groupby(['song_name'])
                .agg({
                    'show_index_overall': ['count', 'min', 'max'],
                    'gap': ['min', 'max', 'mean', 'median', 'std']
                })
                .reset_index()
                .round(2)
)

my_song_data.columns = ['_'.join(col).strip() for col in my_song_data.columns.values]

my_song_data = my_song_data.rename(columns={
    'song_name_': 'song_name', 
    'show_index_overall_count': 'times_played_total', 
    'show_index_overall_min': 'debut', 
    'show_index_overall_max': 'last_played', 
    'gap_min': 'min_gap', 
    'gap_max': 'max_gap', 
    'gap_mean': 'avg_gap',
    'gap_median': 'med_gap',  
    'gap_std': 'std_gap'
})

my_song_data['current_gap'] = last_show - my_song_data['last_played']

my_song_data = (my_song_data
                .merge(showdata[['show_index_overall', 'date']], left_on='debut', right_on='show_index_overall', how='left')
                .rename(columns={'date': 'debut_date'}).drop(columns=['show_index_overall', 'debut'])
                .merge(showdata[['show_index_overall', 'date']], left_on='last_played', right_on='show_index_overall', how='left')
                .rename(columns={'date': 'ltp_date'}).drop(columns=['show_index_overall', 'last_played'])
)[['song_name', 'times_played_total','debut_date','ltp_date','current_gap','avg_gap', 'med_gap', 'std_gap']]

my_song_data['gap_zscore'] = (my_song_data['current_gap'] - my_song_data['avg_gap']) / my_song_data['std_gap']

five_years_ago = date.today() - timedelta(days=5*365)
my_song_data['ltp_date'] = pd.to_datetime(my_song_data['ltp_date'], format='%m/%d/%y').dt.date

my_song_data.head()
# Out:
#                           song_name  times_played_total debut_date  \
# 0           (Don'T Fear) The Reaper                   1   10/28/18
# 1      (Don'T Go Back To) Rockville                   1   12/30/09
# 2  (Sittin' On) The Dock Of The Bay                   4   12/29/05
# 3                             1 X 1                 147   03/23/95
# 4        A Hard Rain'S A-Gonna Fall                  20   12/31/15
#
#      ltp_date  current_gap  avg_gap  med_gap  std_gap  gap_zscore
# 0  2018-10-28          188      NaN      NaN      NaN         NaN
# 1  2009-12-30          725      NaN      NaN      NaN         NaN
# 2  2014-03-29          454   192.00     19.0   314.48    0.833121
# 3  2023-05-27           37    13.71     10.0    15.18    1.534256
# 4  2024-03-22           13    16.68     15.0    13.22   -0.278366

# %%
ck_plus = (my_song_data[(my_song_data['times_played_total'] > 10) & 
                        (my_song_data['ltp_date'] > five_years_ago)].copy()           
           .sort_values(by='gap_zscore', ascending=False)
           .reset_index(drop=True)
           .drop(columns=['debut_date', 'std_gap','gap_zscore'])
)
        
ck_plus['current_minus_avg'] = ck_plus['current_gap'] - ck_plus['avg_gap']
ck_plus['current_minus_med'] = ck_plus['current_gap'] - ck_plus['med_gap']

ck_plus.head()
# Out:
#              song_name  times_played_total    ltp_date  current_gap  avg_gap  \
# 0  Weight Of The World                 588  2022-10-23           64     4.43
# 1            Sell Sell                  76  2022-09-18           69     6.40
# 2         Steven'S Cat                  52  2022-09-16           71     6.08
# 3      It Ain'T No Use                 365  2022-08-11           77     7.52
# 4   You Should Be Glad                 171  2023-02-09           54     6.30
#
#    med_gap  current_minus_avg  current_minus_med
# 0      3.0              59.57               61.0
# 1      5.0              62.60               64.0
# 2      4.0              64.92               67.0
# 3      5.0              69.48               72.0
# 4      5.0              47.70               49.0

# %% [markdown]
# # Split

# %%
setlist_by_song.head(1)
# Out:
#                  song_name set  song_index_set  song_index_show  into  \
# 0  (Don'T Fear) The Reaper  2:              11               19     1
#
#    song_notes_key  notes_id  \
# 0             NaN       NaN
#
#                                                 link  \
# 0  http://www.everydaycompanion.com/setlists/2018...
#
#                song_note_detail  isreprise      date  year  month  day  \
# 0   with Ben Draper on cowbell           0  10/28/18  2018     10   28
#
#   weekday   date_ec         venue       city state  show_index_overall  \
# 0  Sunday  10/28/18  PARK THEATER  LAS VEGAS    NV                3027
#
#    show_index_withinyear  run_index                   venue_full  gap
# 0                     32       2423  PARK THEATER, LAS VEGAS, NV  NaN

# %%
one_year_ago = date.today() - timedelta(days=2*366)
setlist_by_song['date'] = pd.to_datetime(setlist_by_song['date'], format='%m/%d/%y').dt.date

jojos_notebook_data = (setlist_by_song[setlist_by_song['date'] > one_year_ago]
                       ).reset_index(drop=True)[['song_name', 'show_index_overall', 'date','gap']]

jojos_notebook_data.head()
# Out:
#                     song_name  show_index_overall        date   gap
# 0                       1 X 1                3178  2023-05-27  29.0
# 1  A Hard Rain'S A-Gonna Fall                3181  2023-06-24  21.0
# 2  A Hard Rain'S A-Gonna Fall                3202  2024-03-22  21.0
# 3                      A Of D                3164  2023-03-03  15.0
# 4               Ace Of Spades                3173  2023-04-19  22.0

# %%
jojos_notebook = (
            jojos_notebook_data
            .groupby(['song_name'])
            .agg({
                'show_index_overall': ['count', 'max'],
                'gap': ['min', 'max', 'mean', 'median', 'std']
            })
            .reset_index()
            .round(2)
        )
jojos_notebook.columns = ['_'.join(col).strip() for col in jojos_notebook.columns.values]

jojos_notebook = jojos_notebook.rename(columns={
    'song_name_': 'song', 
    'show_index_overall_count': 'times_played_in_last_year', 
    'show_index_overall_max': 'last_played', 
    'gap_min': 'min_gap', 
    'gap_max': 'max_gap', 
    'gap_mean': 'avg_gap',
    'gap_median': 'med_gap',  
    'gap_std': 'std_gap'
})

jojos_notebook['current_gap'] = last_show - jojos_notebook['last_played']

jojos_notebook = (
    jojos_notebook
    .merge(
        showdata[['show_index_overall', 'date']], 
        left_on='last_played', 
        right_on='show_index_overall', 
        how='left'
        )
    .rename(columns={'date': 'ltp_date'})
    .drop(columns=['show_index_overall', 'last_played'])
    )[['song', 'times_played_in_last_year', 'ltp_date','current_gap', 'avg_gap', 'med_gap']]
        
jojos_notebook.head()
# Out:
#                          song  times_played_in_last_year  last_played  \
# 0                       1 X 1                          1         3178
# 1  A Hard Rain'S A-Gonna Fall                          2         3202
# 2                      A Of D                          1         3164
# 3               Ace Of Spades                          1         3173
# 4                  Action Man                          8         3215
#
#    min_gap  max_gap  avg_gap  med_gap  std_gap  current_gap
# 0     29.0     29.0    29.00     29.0      NaN           37
# 1     21.0     21.0    21.00     21.0     0.00           13
# 2     15.0     15.0    15.00     15.0      NaN           51
# 3     22.0     22.0    22.00     22.0      NaN           42
# 4      4.0     10.0     6.62      5.5     2.39            0

# %%
jojos_notebook = (
    jojos_notebook[(jojos_notebook['current_gap'] > 3)]
    .sort_values(by='times_played_in_last_year', ascending=False)
    .reset_index(drop=True)
)

jojos_notebook.head()
# Out:
#                  song  times_played_in_last_year  ltp_date  current_gap  \
# 0                Rock                         12  05/25/24            4
# 1  Henry Parsons Died                         11  05/24/24            5
# 2               Disco                         11  05/25/24            4
# 3           Wondering                         10  04/25/24            6
# 4   Big Wooly Mammoth                         10  05/25/24            4
#
#    avg_gap  med_gap
# 0     4.42      5.0
# 1     4.45      4.0
# 2     4.64      4.0
# 3     4.80      5.0
# 4     5.20      5.0

# %%
jojos_notebook = (jojos_notebook[(jojos_notebook['current_gap'] > 3)].sort_values(by='times_played_in_last_year', ascending=False)
                  .reset_index(drop=True)
)

jojos_notebook.head()
# Out:
#             song_name  times_played_in_last_year   ltp_date  current_gap  \
# 0  HENRY PARSONS DIED                         14 2024-05-24            5
# 1                ROCK                         14 2024-05-25            4
# 2           WONDERING                         13 2024-04-25            6
# 3               DISCO                         13 2024-05-25            4
# 4               DINER                         12 2024-05-25            4
#
#    avg_gap  med_gap
# 0     3.71      4.0
# 1     3.79      5.0
# 2     4.15      5.0
# 3     3.92      4.0
# 4     4.33      4.5

# %%
# Saving all datasets to CSV
try:
    script_dir = os.path.dirname(os.path.abspath(__file__))
except NameError:
    script_dir = os.getcwd()
base_dir = os.path.dirname(script_dir)
save_path = os.path.join(base_dir, "Data", "Widespread_Panic")
ck_plus.to_csv(os.path.join(save_path, "ckplus_wsp.csv"), index=False)
jojos_notebook.to_csv(os.path.join(save_path, "jojos_notebook.csv"), index=False)
