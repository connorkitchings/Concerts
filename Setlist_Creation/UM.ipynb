# %%
import pandas as pd
import numpy as np
import requests
import re
from bs4 import BeautifulSoup
from io import StringIO

# %%
# Pulling Song Data from All Things Umphreys Website
songlist_url = "https://allthings.umphreys.com/song/"
response = requests.get(songlist_url)
response.raise_for_status()  # Raise an exception for bad status codes
html_content = response.text
soup = BeautifulSoup(html_content, 'html.parser')
tables = soup.find_all('table')
if tables:
    tables_str = str(tables)  # Convert tables to string
    tables_io = StringIO(tables_str)  # Wrap in StringIO
    tables = pd.read_html(tables_io)
songdata_info = tables[1].copy().sort_values(by='Song Name').reset_index(drop=True)
songdata_info.head()
# Out:
#                       Song Name Original Artist  Debut Date Last Played  \
# 0  "Brendan & Jake switch rigs"             NaN  2010-04-24  2021-08-22
# 1              "Mirro Memories"             NaN  2022-11-12  2022-11-12
# 2        "Mrs Robinson's Strut"             NaN  2011-04-02  2011-04-02
# 3                           #19             NaN  2011-04-02  2011-04-02
# 4                            #5             NaN  2003-05-15  2024-12-12
#
#    Times Played Live  Avg Show Gap
# 0                  2        438.00
# 1                  1        180.00
# 2                  1       1206.00
# 3                  1       1206.00
# 4                173         12.91

# %%
venues_url = "https://allthings.umphreys.com/venues/"
response = requests.get(venues_url)
response.raise_for_status()  # Raise an exception for bad status codes
html_content = response.text
soup = BeautifulSoup(html_content, 'html.parser')
tables = soup.find_all('table')
if tables:
    tables_str = str(tables)  # Convert tables to string
    tables_io = StringIO(tables_str)  # Wrap in StringIO
    tables = pd.read_html(tables_io)
venue_data = tables[0].copy().reset_index(names='id')
venue_data['id'] = venue_data['id'].astype(str)
venue_data.head()
# Out:
#   id              Venue Name          City State Country  Times Played  \
# 0  0           1 Up - Colfax        Denver    CO     USA             1
# 1  1           12th & Porter     Nashville    TN     USA             3
# 2  2          20 Monroe Live  Grand Rapids    MI     USA             1
# 3  3  203 East Marion Street    South Bend    IN     USA             1
# 4  4    20th Century Theatre    Cincinnati    OH     USA             2
#
#   Last Played
# 0  2013-12-30
# 1  2003-10-02
# 2  2017-02-02
# 3  1998-10-02
# 4  2002-11-15

# %%
song_replacements = {
     "Mirro Memories": "Mirro Memories"
}

# %%
song_list = songdata_info['Song Name'].unique().tolist()
songs_to_drop = ['"Mirro Memories"']
song_changes = {
    "Forty-Six & 2": "Forty-Six"
}
song_list = [song for song in song_list if song not in songs_to_drop]
song_list = [song_changes.get(song, song) for song in song_list]

# %%
newsong_list = []
for song in song_list:
    new_song = song.replace('"', 'quot').replace('&', 'amp').replace("...", "")
    new_song = re.sub(r"[#():',.]", "", new_song).lower()
    new_song = new_song.replace(" ", "-")
    newsong_list.append(new_song)

# %%
base_url = showlist_url_base = "https://allthings.umphreys.com/song/"
test_list = newsong_list[26:100]
song_history1 = []
i = 1
for song in test_list:
    if i % 25 == 0:
        print(f"Scraping song {i} of {len(newsong_list)}")
    url = base_url + song
    response = requests.get(url)
    response.raise_for_status()  # Raise an exception for bad status codes
    html_content = response.text
    soup = BeautifulSoup(html_content, 'html.parser')
    tables = soup.find_all('table')
    if tables:
        tables_str = str(tables)  # Convert tables to string
        tables_io = StringIO(tables_str)  # Wrap in StringIO
        tables = pd.read_html(tables_io)
    table = tables[0].rename(columns={'Date Played': 'Date'})
    table['song'] = song.replace("-", " ").replace("quot", '"').replace("amp", "&").upper()
    song_history1.append(table)
    i += 1

song_history = pd.concat(song_history1).reset_index(drop=True)
song_history
# Out:
# Scraping song 25 of 1009
# Scraping song 50 of 1009
#             Date                                              Venue  Show Gap  \
# 0     2007-12-31                       Aragon Ballroom, Chicago, IL    1229.0
# 1     2008-05-01                       Market Square, Knoxville, TN      38.0
# 2     2009-06-27  Paper Mill Island Amphitheater, Baldwinsville, NY    1397.0
# 3     2011-01-30                    Ram's Head Live!, Baltimore, MD     184.0
# 4     2011-12-29                         The Pageant, St. Louis, MO     100.0
# ...          ...                                                ...       ...
# 3666  2001-05-03                The Vogue Theatre, Indianapolis, IN      51.0
# 3667  2003-07-08                       House of Glass, Dunsmuir, CA     342.0
# 3668  2009-04-18  The Morris Performing Arts Center, South Bend, IN     759.0
# 3669  2018-08-11  Farm Bureau Insurance Lawn at White River Stat...     969.0
# 3670  2018-07-20                     Montage Mountain, Scranton, PA    2347.0
#
#      Set            Song Before           Song After  \
# 0      1       Der Bluten Kat >     > Der Bluten Kat
# 1      1     Intentions Clear >      Trenchtown Rock
# 2      1            Divisions >     > Get In The Van
# 3      2         Phil's Farm ->          > Blue Echo
# 4      2     Cemetery Walk II >   > Cemetery Walk II
# ...   ..                    ...                  ...
# 3666   1      Last Man Swerving  > Nothing Too Fancy
# 3667   2               Roulette            > 13 Days
# 3668   1  White Man's Moccasins      End of the Road
# 3669   2                    ***            Divisions
# 3670   1            Utopian Fir          Attachments
#
#                                                Footnote            song    0  \
# 0     debut, Jeff Coffin; with Jeff Coffin on saxophone    A HALF SLEEP  NaN
# 1                         with Jeff Coffin on saxophone    A HALF SLEEP  NaN
# 2                                  debut, John Coltrane  A LOVE SUPREME  NaN
# 3                                                   NaN  A LOVE SUPREME  NaN
# 4                                                   NaN  A LOVE SUPREME  NaN
# ...                                                 ...             ...  ...
# 3666                                                NaN        BIRTHDAY  NaN
# 3667            with Sunshine Superman (Donovan) teases        BIRTHDAY  NaN
# 3668                    with Steve Krojniewski on drums        BIRTHDAY  NaN
# 3669                                                NaN        BIRTHDAY  NaN
# 3670  debut, The Rolling Stones; with Chris Brouwers...           BITCH  NaN
#
#        1    2
# 0    NaN  NaN
# 1    NaN  NaN
# 2    NaN  NaN
# 3    NaN  NaN
# 4    NaN  NaN
# ...   ..  ...
# 3666 NaN  NaN
# 3667 NaN  NaN
# 3668 NaN  NaN
# 3669 NaN  NaN
# 3670 NaN  NaN
#
# [3671 rows x 11 columns]

# %%
showlist_url1 = "https://allthings.umphreys.com/setlists/umphreys-mcgee"
response = requests.get(showlist_url1)
response.raise_for_status()  # Raise an exception for bad status codes
html_content = response.text
soup = BeautifulSoup(html_content, 'html.parser')
selects = soup.find_all('select')
years_html = selects[1]
years_list = [option['value'] for option in years_html.find_all('option') if option['value'].isdigit()][::-1]

# %%
showlist_url_base = "https://allthings.umphreys.com/setlists/umphreys-mcgee/"
test_list = years_list[0:1]
year_data = []
for year in test_list:
    url = showlist_url_base + year
    response = requests.get(url)
    response.raise_for_status()  # Raise an exception for bad status codes
    html_content = response.text
    soup = BeautifulSoup(html_content, 'html.parser')
    divs = soup.find_all('div')
    #if tables:
    #    tables_str = str(tables)  # Convert tables to string
    #    tables_io = StringIO(tables_str)  # Wrap in StringIO
    #    tables = pd.read_html(tables_io)
    #raw = tables[0].copy()
    
divs
# Out:
# [<div class="padded-body">
#  <div class="container-fluid">
#  <nav class="primary-navigation navbar navbar-expand-lg navbar navbar-light sticky-top text-dark" style="background-color:#fff;">
#  <div class="container-fluid">
#  <a class="navbar-brand" href="/">
#  <img alt="All Things Umphrey's" class="d-inline-block" src="https://i.songfishapp.com/allthingsum/62c5d97030c41-logo-black.png" style="max-width:400px;max-height:45px;"/>
#  </a>
#  <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarSupportedContent" data-bs-toggle="collapse" type="button">
#  <span class="navbar-toggler-icon"></span>
#  </button>
#  <div class="collapse navbar-collapse" id="navbarSupportedContent">
#  <ul class="navbar-nav ms-auto">
#  <li class="nav-item">
#  <a class="nav-link" href="/">Home</a>
#  </li>
#  <li class="nav-item dropdown">
#  <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="#" id="navbarDropdown" role="button">
#            Shows        </a>
#  <ul aria-labelledby="navbarDropdown" class="dropdown-menu" style="background-color:#fff;">
#  <li><a class="dropdown-item" href="/setlists/">Setlists</a></li>
#  <li><a class="dropdown-item" href="/venues/">Venues</a></li>
#  <li><a class="dropdown-item" href="/reviews/">Reviews</a></li>
#  <li><a class="dropdown-item" href="https://www.umphreys.com/tour/" target="_blank">Upcoming Shows</a></li>
#  </ul>
#  </li>
#  <li class="nav-item dropdown">
#  <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="#" id="navbarDropdown" role="button">
#            Music        </a>
#  <ul aria-labelledby="navbarDropdown" class="dropdown-menu" style="background-color:#fff;">
#  <li><a class="dropdown-item" href="/song/">Songs</a></li>
#  <li><a class="dropdown-item" href="/discography">Releases</a></li>
#  <li><a class="dropdown-item" href="/metadata/jimmy-stewart">Jimmy Stewarts</a></li>
#  <li><a class="dropdown-item" href="/setlists/debuts/">Debut Chart</a></li>
#  <li><a class="dropdown-item" href="/charts/guests">Guest Appearances</a></li>
#  </ul>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="/stats/">Stats</a>
#  </li>
#  <li class="nav-item dropdown">
#  <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="#" id="navbarDropdown" role="button">
#            Site        </a>
#  <ul aria-labelledby="navbarDropdown" class="dropdown-menu" style="background-color:#fff;">
#  <li><a class="dropdown-item" href="/faq">FAQ</a></li>
#  <li><a class="dropdown-item" href="/api/docs">API</a></li>
#  </ul>
#  </li>
#  <li class="nav-item dropdown">
#  <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="#" id="navbarDropdown" role="button">
#            Social        </a>
#  <ul aria-labelledby="navbarDropdown" class="dropdown-menu" style="background-color:#fff;">
#  <li><a class="dropdown-item" href="https://facebook.com/umphreysmcgee" target="_blank"><i class="fab fa-facebook-square"></i> Facebook</a></li>
#  <li><a class="dropdown-item" href="https://twitter.com/umphreysmcgee" target="_blank"><i class="fab fa-twitter-square"></i> Twitter</a></li>
#  <li><a class="dropdown-item" href="https://instagram.com/umphreysmcgee" target="_blank"><i class="fab fa-instagram-square"></i> Instagram</a></li>
#  <li><a class="dropdown-item" href="https://shakedown.social/@umphreys" target="_blank"><i class="fab fa-mastodon"></i> Mastodon</a></li>
#  </ul>
#  </li>
#  <li class="nav-item">
#  <a class="nav-link" href="https://www.umphreys.com">um.com</a>
#  </li>
#  <li class="nav-item dropdown" id="nav-form-reveal">
#  <a class="nav-link" data-bs-target="#setlist-jump" data-bs-toggle="modal" href="#" onclick="$('#jump-date').focus();" title="Jump to a setlist">
#  <i class="fa-solid fa-broom"></i>
#  </a>
#  </li>
#  <li class="nav-item dropdown">
#  <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="#" id="navbarDropdown" role="button">
#            Account <span class="caret"></span>
#  </a>
#  <ul aria-labelledby="navbarDropdown" class="dropdown-menu" style="background-color:#fff;">
#  <li><a class="dropdown-item" href="/login">Login</a></li>
#  <li><a class="dropdown-item" href="/register">Create Account</a></li>
#  </ul>
#  </li>
#  </ul></div>
#  </div>
#  </nav>
#  <!-- setlist jump modal -->
#  <div class="modal rounded" id="setlist-jump" tabindex="-1">
#  <div class="modal-dialog">
#  <div class="modal-content">
#  <div class="modal-header bg-dark text-light">
#  <h5 class="modal-title">Jump to a setlist</h5>
#  <button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button"></button>
#  </div>
#  <div class="modal-body">
#  <input aria-label="Jump to setlist" class="form-control" id="jump-date" placeholder="Jump to..." type="date"/>
#  </div>
#  <div class="modal-footer">
#  <button class="btn-sm btn btn-secondary" data-bs-dismiss="modal" type="button">Close</button>
#  <button class="btn-sm btn btn-primary btn-setlist-jump text-nowrap" onclick="location.href='/setlists/?date='+$('#jump-date').val();" type="button">Jump!</button>
#  </div>
#  </div>
#  </div>
#  </div><br/><div class="row" style="margin-bottom:.5em;">
#  <span class="p-3 bg-dark text-light rounded setlist-filter-box">Shows by <select class="selectpicker" onchange="location.href='/setlists/'+$(this).val()+'/1998';">
#  <option value="">All</option>
#  <option selected="selected" value="umphreys-mcgee">Umphrey's McGee</option>
#  <option value="brendan-and-jake">Brendan and Jake</option>
#  </select>
#   played in <select onchange="location.href='/setlists/umphreys-mcgee/'+$(this).val();"><option value="">recent shows</option><option value="2025">2025</option>
#  <option value="2024">2024</option>
#  <option value="2023">2023</option>
#  <option value="2022">2022</option>
#  <option value="2021">2021</option>
#  <option value="2020">2020</option>
#  <option value="2019">2019</option>
#  <option value="2018">2018</option>
#  <option value="2017">2017</option>
#  <option value="2016">2016</option>
#  <option value="2015">2015</option>
#  <option value="2014">2014</option>
#  <option value="2013">2013</option>
#  <option value="2012">2012</option>
#  <option value="2011">2011</option>
#  <option value="2010">2010</option>
#  <option value="2009">2009</option>
#  <option value="2008">2008</option>
#  <option value="2007">2007</option>
#  <option value="2006">2006</option>
#  <option value="2005">2005</option>
#  <option value="2004">2004</option>
#  <option value="2003">2003</option>
#  <option value="2002">2002</option>
#  <option value="2001">2001</option>
#  <option value="2000">2000</option>
#  <option value="1999">1999</option>
#  <option selected="selected" value="1998">1998</option>
#  </select></span>
#  </div><div id="setlist-container"><div id="setlistsmain"><div id="setlist-calendar"><br/>January 1998: <a class="sl-calendar" href="#setlist-1998-01-21">21</a> | <a class="sl-calendar" href="#setlist-1998-01-29">29</a> | <a class="sl-calendar" href="#setlist-1998-01-31">31</a> <br/>February 1998: <a class="sl-calendar" href="#setlist-1998-02-07">07</a> | <a class="sl-calendar" href="#setlist-1998-02-11">11</a> | <a class="sl-calendar" href="#setlist-1998-02-19">19</a> | <a class="sl-calendar" href="#setlist-1998-02-20">20</a> | <a class="sl-calendar" href="#setlist-1998-02-27">27</a> | <a class="sl-calendar" href="#setlist-1998-02-28">28</a> <br/>March 1998: <a class="sl-calendar" href="#setlist-1998-03-05">05</a> | <a class="sl-calendar" href="#setlist-1998-03-19">19</a> | <a class="sl-calendar" href="#setlist-1998-03-20">20</a> | <a class="sl-calendar" href="#setlist-1998-03-27">27</a> | <a class="sl-calendar" href="#setlist-1998-03-28">28</a> <br/>April 1998: <a class="sl-calendar" href="#setlist-1998-04-01">01</a> | <a class="sl-calendar" href="#setlist-1998-04-04">04</a> | <a class="sl-calendar" href="#setlist-1998-04-15">15</a> | <a class="sl-calendar" href="#setlist-1998-04-17">17</a> | <a class="sl-calendar" href="#setlist-1998-04-20">20</a> | <a class="sl-calendar" href="#setlist-1998-04-22">22</a> | <a class="sl-calendar" href="#setlist-1998-04-24">24</a> | <a class="sl-calendar" href="#setlist-1998-04-25">25</a> | <a class="sl-calendar" href="#setlist-1998-04-25">25</a> | <a class="sl-calendar" href="#setlist-1998-04-29">29</a> <br/>May 1998: <a class="sl-calendar" href="#setlist-1998-05-02">02</a> | <a class="sl-calendar" href="#setlist-1998-05-08">08</a> | <a class="sl-calendar" href="#setlist-1998-05-13">13</a> | <a class="sl-calendar" href="#setlist-1998-05-16">16</a> | <a class="sl-calendar" href="#setlist-1998-05-21">21</a> | <a class="sl-calendar" href="#setlist-1998-05-22">22</a> | <a class="sl-calendar" href="#setlist-1998-05-23">23</a> | <a class="sl-calendar" href="#setlist-1998-05-27">27</a> <br/>June 1998: <a class="sl-calendar" href="#setlist-1998-06-05">05</a> | <a class="sl-calendar" href="#setlist-1998-06-06">06</a> <br/>August 1998: <a class="sl-calendar" href="#setlist-1998-08-22">22</a> | <a class="sl-calendar" href="#setlist-1998-08-27">27</a> | <a class="sl-calendar" href="#setlist-1998-08-29">29</a> <br/>September 1998: <a class="sl-calendar" href="#setlist-1998-09-05">05</a> | <a class="sl-calendar" href="#setlist-1998-09-11">11</a> | <a class="sl-calendar" href="#setlist-1998-09-12">12</a> | <a class="sl-calendar" href="#setlist-1998-09-17">17</a> | <a class="sl-calendar" href="#setlist-1998-09-18">18</a> | <a class="sl-calendar" href="#setlist-1998-09-19">19</a> | <a class="sl-calendar" href="#setlist-1998-09-25">25</a> <br/>October 1998: <a class="sl-calendar" href="#setlist-1998-10-01">01</a> | <a class="sl-calendar" href="#setlist-1998-10-02">02</a> | <a class="sl-calendar" href="#setlist-1998-10-09">09</a> | <a class="sl-calendar" href="#setlist-1998-10-10">10</a> | <a class="sl-calendar" href="#setlist-1998-10-25">25</a> | <a class="sl-calendar" href="#setlist-1998-10-28">28</a> | <a class="sl-calendar" href="#setlist-1998-10-29">29</a> | <a class="sl-calendar" href="#setlist-1998-10-31">31</a> <br/>November 1998: <a class="sl-calendar" href="#setlist-1998-11-04">04</a> | <a class="sl-calendar" href="#setlist-1998-11-13">13</a> | <a class="sl-calendar" href="#setlist-1998-11-14">14</a> | <a class="sl-calendar" href="#setlist-1998-11-20">20</a> | <a class="sl-calendar" href="#setlist-1998-11-27">27</a> <br/>December 1998: <a class="sl-calendar" href="#setlist-1998-12-09">09</a> | <a class="sl-calendar" href="#setlist-1998-12-11">11</a> | <a class="sl-calendar" href="#setlist-1998-12-17">17</a> | <a class="sl-calendar" href="#setlist-1998-12-18">18</a> </div><section class="setlist-artist-1">
#  <div class="setlist setlist-container">
#  <a class="setlist-anchor" name="setlist-1998-01-21"></a>
#  <div class="setlist-header">
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-january-21-1998-bridget-mcguires-filling-station-south-bend-in-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-january-21-1998-bridget-mcguires-filling-station-south-bend-in-usa.html">January 21, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/bridget-mcguires-filling-station-south-bend-in-usa" target="_top">Bridget McGuire's Filling Station</a> — <a href="/venues/city/South+Bend/IN" target="_top">South Bend</a>, <a href="/venues/state/IN/USA" target="_top">IN</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>
#  </div>
#  <div class="setlist-body"><br/>
#  <p><b class="setlabel set-1">Set 1:</b> <span class="setlist-songbox"><a class="" href="/song/bob" title="Bob">Bob</a><sup title="debut, original; with false start">[1]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/red-baron" title="Red Baron">Red Baron</a><sup title="debut, Billy Cobham; with Birthday wishes from Mike">[2]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/divisions" title="Divisions">Divisions</a><sup title="debut, original">[3]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/burning-down-the-house" title="Burning Down the House">Burning Down the House</a><sup title="debut, Talking Heads">[4]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/muffburger-sandwich" title="Muffburger Sandwich">Muffburger Sandwich</a><sup title="debut, original">[3]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/philosophy" title="Philosophy">Philosophy</a><sup title="debut, Ben Folds Five">[5]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/linus-and-lucy" title="Linus and Lucy">Linus and Lucy</a><sup title="debut, Vince Guaraldi">[6]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/philosophy" title="Philosophy">Philosophy</a> </span> </p><p><b class="setlabel set-2">Set 2:</b> <span class="setlist-songbox"><a class="" href="/song/intro" title="Intro">Intro</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/10th-grade" title="10th Grade">10th Grade</a><sup title="debut, original">[3]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/moby-dick" title="Moby Dick">Moby Dick</a><sup title="debut, Led Zeppelin">[7]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/ff" title="FF">FF</a><sup title="debut, original">[3]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/phils-farm" title="Phil's Farm">Phil's Farm</a><sup title="debut, original">[3]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/mikes-song" title="Mike's Song">Mike's Song</a><sup title="debut, Phish">[8]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/i-am-hydrogen" title="I Am Hydrogen">I Am Hydrogen</a><sup title="debut, Phish">[8]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/weekapaug-groove" title="Weekapaug Groove">Weekapaug Groove</a><sup title="debut, Phish">[8]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/orfeo" title="Orfeo">Orfeo</a><sup title="debut, original">[3]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/hours" title="Hours">Hours</a><sup title="debut, original">[3]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/kimble" title="Kimble">Kimble</a><sup title="debut, original">[3]</sup> </span> </p><p><b class="setlabel set-e">Encore:</b> <span class="setlist-songbox"><a class="" href="/song/pour-some-sugar-on-me" title="Pour Some Sugar On Me">Pour Some Sugar On Me</a><sup title="debut, Def Leppard">[9]</sup> </span> </p><p><b class="setlabel set-e2">2<sup>nd</sup> Encore:</b> <span class="setlist-songbox"><a class="" href="/song/bathtub-gin" title="Bathtub Gin">Bathtub Gin</a><sup title="debut, Phish">[8]</sup></span> </p>
#  </div>
#  <div class="setlist-footer">
#  <p class="setlist-footnotes"><b>Footnotes</b>:<br/>    [1] debut, original; with false start<br/>    [2] debut, Billy Cobham; with Birthday wishes from Mike<br/>    [3] debut, original<br/>    [4] debut, Talking Heads<br/>    [5] debut, Ben Folds Five<br/>    [6] debut, Vince Guaraldi<br/>    [7] debut, Led Zeppelin<br/>    [8] debut, Phish<br/>    [9] debut, Def Leppard</p>
#  <p><b class="shownotes-label">Show Notes:</b> First Umphrey's McGee show</p>
#  </div>
#  </div>
#  </section><section class="setlist-artist-1">
#  <div class="setlist setlist-container">
#  <a class="setlist-anchor" name="setlist-1998-01-29"></a>
#  <div class="setlist-header">
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-january-29-1998-club-23-south-bend-in-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-january-29-1998-club-23-south-bend-in-usa.html">January 29, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/club-23-south-bend-in-usa" target="_top">Club 23</a> — <a href="/venues/city/South+Bend/IN" target="_top">South Bend</a>, <a href="/venues/state/IN/USA" target="_top">IN</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>
#  </div>
#  <div class="setlist-body"><br/>
#  <p><b class="setlabel set-1">Set 1:</b> <span class="setlist-songbox"><a class="" href="/song/phils-farm" title="Phil's Farm">Phil's Farm</a>, </span> <span class="setlist-songbox"><a class="" href="/song/hours" title="Hours">Hours</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/kimble" title="Kimble">Kimble</a>, </span> <span class="setlist-songbox"><a class="" href="/song/red-baron" title="Red Baron">Red Baron</a>, </span> <span class="setlist-songbox"><a class="" href="/song/muffburger-sandwich" title="Muffburger Sandwich">Muffburger Sandwich</a>, </span> <span class="setlist-songbox"><a class="" href="/song/philosophy" title="Philosophy">Philosophy</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/linus-and-lucy" title="Linus and Lucy">Linus and Lucy</a><sup title="ended with Rhapsody in Blue (George Gershwin) tease">[1]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/philosophy" title="Philosophy">Philosophy</a>, </span> <span class="setlist-songbox"><a class="" href="/song/divisions" title="Divisions">Divisions</a>, </span> <span class="setlist-songbox"><a class="" href="/song/rebubula" title="Rebubula">Rebubula</a><sup title="debut, moe.; with Norwegian Wood (The Beatles) tease">[2]</sup> </span> </p><p><b class="setlabel set-2">Set 2:</b> <span class="setlist-songbox"><a class="" href="/song/g-song" title="G-Song">G-Song</a><sup title="debut, original">[3]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/bubblehouse" title="Bubblehouse">Bubblehouse</a><sup title="debut, Medeski Martin &amp; Wood">[4]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/g-song" title="G-Song">G-Song</a>, </span> <span class="setlist-songbox"><a class="" href="/song/ff" title="FF">FF</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/jump" title="Jump">Jump</a><sup title="debut, Van Halen">[5]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/ff" title="FF">FF</a>, </span> <span class="setlist-songbox"><a class="" href="/song/burning-down-the-house" title="Burning Down the House">Burning Down the House</a><sup title="with Underworld (Super Mario Brothers) theme (Koji Kondo) and Scarlet Begonias (The Grateful Dead) teases">[6]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/10th-grade" title="10th Grade">10th Grade</a><sup title="with Third Sone from the Sun (Jimi Hendrix) teases">[7]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/mikes-song" title="Mike's Song">Mike's Song</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/phils-farm" title="Phil's Farm">Phil's Farm</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/i-am-hydrogen" title="I Am Hydrogen">I Am Hydrogen</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/weekapaug-groove" title="Weekapaug Groove">Weekapaug Groove</a><sup title="with All In Time tease">[8]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/orfeo" title="Orfeo">Orfeo</a>, </span> <span class="setlist-songbox"><a class="" href="/song/moby-dick" title="Moby Dick">Moby Dick</a><sup title="with 50 Ways to Leave Your Lover (Paul Simon) tease and verse as well as Tweezer (Phish) and Thunderstruck (AC/DC) teases">[9]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/dear-lord" title="Dear Lord">Dear Lord</a><sup title="debut, original; with Mellow Mood and Stir It Up (both Bob Marley) and The Tide Is High (Blondie) quotes from Brendan">[10]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/pour-some-sugar-on-me" title="Pour Some Sugar On Me">Pour Some Sugar On Me</a></span> </p>
#  </div>
#  <div class="setlist-footer">
#  <p class="setlist-footnotes"><b>Footnotes</b>:<br/>    [1] ended with Rhapsody in Blue (George Gershwin) tease<br/>    [2] debut, moe.; with Norwegian Wood (The Beatles) tease<br/>    [3] debut, original<br/>    [4] debut, Medeski Martin &amp; Wood<br/>    [5] debut, Van Halen<br/>    [6] with Underworld (Super Mario Brothers) theme (Koji Kondo) and Scarlet Begonias (The Grateful Dead) teases<br/>    [7] with Third Sone from the Sun (Jimi Hendrix) teases<br/>    [8] with All In Time tease<br/>    [9] with 50 Ways to Leave Your Lover (Paul Simon) tease and verse as well as Tweezer (Phish) and Thunderstruck (AC/DC) teases<br/>    [10] debut, original; with Mellow Mood and Stir It Up (both Bob Marley) and The Tide Is High (Blondie) quotes from Brendan</p>
#  </div>
#  </div>
#  </section><section class="setlist-artist-1">
#  <div class="setlist setlist-container">
#  <a class="setlist-anchor" name="setlist-1998-01-31"></a>
#  <div class="setlist-header">
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-january-31-1998-marion-street-south-bend-in-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-january-31-1998-marion-street-south-bend-in-usa.html">January 31, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/marion-street-south-bend-in-usa" target="_top">Marion Street</a> — <a href="/venues/city/South+Bend/IN" target="_top">South Bend</a>, <a href="/venues/state/IN/USA" target="_top">IN</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>
#  </div>
#  <div class="setlist-body"><br/>
#  <p><b class="setlabel set-1">Set 1:</b> <span class="setlist-songbox"><a class="" href="/song/10th-grade" title="10th Grade">10th Grade</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/hajimemashite" title="Hajimemashite">Hajimemashite</a><sup title="debut, original">[1]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/10th-grade" title="10th Grade">10th Grade</a>, </span> <span class="setlist-songbox"><a class="" href="/song/bob" title="Bob">Bob</a>, </span> <span class="setlist-songbox"><a class="" href="/song/divisions" title="Divisions">Divisions</a>, </span> <span class="setlist-songbox"><a class="" href="/song/burning-down-the-house" title="Burning Down the House">Burning Down the House</a>, </span> <span class="setlist-songbox"><a class="" href="/song/ff" title="FF">FF</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/jump" title="Jump">Jump</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/ff" title="FF">FF</a>, </span> <span class="setlist-songbox"><a class="" href="/song/phils-farm" title="Phil's Farm">Phil's Farm</a>, </span> <span class="setlist-songbox"><a class="" href="/song/cantaloupe-woman" title="Cantaloupe Woman">Cantaloupe Woman</a><sup title="debut, Grant Green">[2]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/divisions" title="Divisions">Divisions</a>, </span> <span class="setlist-songbox"><a class="" href="/song/rebubula" title="Rebubula">Rebubula</a> </span> </p><p><b class="setlabel set-2">Set 2:</b> <span class="setlist-songbox"><a class="" href="/song/hours" title="Hours">Hours</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/kimble" title="Kimble">Kimble</a>, </span> <span class="setlist-songbox"><a class="" href="/song/muffburger-sandwich" title="Muffburger Sandwich">Muffburger Sandwich</a>, </span> <span class="setlist-songbox"><a class="" href="/song/g-song" title="G-Song">G-Song</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/red-baron" title="Red Baron">Red Baron</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/g-song" title="G-Song">G-Song</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/bubblehouse" title="Bubblehouse">Bubblehouse</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/g-song" title="G-Song">G-Song</a>, </span> <span class="setlist-songbox"><a class="" href="/song/sweet-child-o-mine" title="Sweet Child o' Mine">Sweet Child o' Mine</a><sup title="debut, Guns N' Roses">[3]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/mikes-song" title="Mike's Song">Mike's Song</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/i-am-hydrogen" title="I Am Hydrogen">I Am Hydrogen</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/weekapaug-groove" title="Weekapaug Groove">Weekapaug Groove</a> &gt; </span> <span class="setlist-songbox"><a class="jamchart" data-bs-custom-class="setlist-tooltip" data-bs-placement="top" data-bs-toggle="tooltip" href="/song/orfeo" title="">Orfeo</a>, </span> <span class="setlist-songbox"><a class="" href="/song/moby-dick" title="Moby Dick">Moby Dick</a><sup title="with Steve Krojniewski on percussion">[4]</sup></span> </p>
#  </div>
#  <div class="setlist-footer">
#  <p class="setlist-footnotes"><b>Footnotes</b>:<br/>    [1] debut, original<br/>    [2] debut, Grant Green<br/>    [3] debut, Guns N' Roses<br/>    [4] with Steve Krojniewski on percussion</p>
#  </div>
#  </div>
#  </section><section class="setlist-artist-1">
#  <div class="setlist setlist-container">
#  <a class="setlist-anchor" name="setlist-1998-02-07"></a>
#  <div class="setlist-header">
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-february-7-1998-benchwarmers-south-bend-in-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-february-7-1998-benchwarmers-south-bend-in-usa.html">February 7, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/benchwarmers-south-bend-in-usa" target="_top">Benchwarmers</a> — <a href="/venues/city/South+Bend/IN" target="_top">South Bend</a>, <a href="/venues/state/IN/USA" target="_top">IN</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>
#  </div>
#  <div class="setlist-body"><br/>
#  <p><b class="setlabel set-1">One Set:</b> <span class="setlist-songbox"><a class="" href="/song/10th-grade" title="10th Grade">10th Grade</a>, </span> <span class="setlist-songbox"><a class="" href="/song/all-in-time" title="All In Time">All In Time</a><sup title="debut, original">[1]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/red-baron" title="Red Baron">Red Baron</a>, </span> <span class="setlist-songbox"><a class="" href="/song/divisions" title="Divisions">Divisions</a>, </span> <span class="setlist-songbox"><a class="" href="/song/bob" title="Bob">Bob</a>, </span> <span class="setlist-songbox"><a class="" href="/song/vibe" title="Vibe">Vibe</a><sup title="debut, original (Stomper Bob)">[2]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/g-song" title="G-Song">G-Song</a>, </span> <span class="setlist-songbox"><a class="" href="/song/kimble" title="Kimble">Kimble</a>, </span> <span class="setlist-songbox"><a class="" href="/song/rebubula" title="Rebubula">Rebubula</a>, </span> <span class="setlist-songbox"><a class="" href="/song/muffburger-sandwich" title="Muffburger Sandwich">Muffburger Sandwich</a>, </span> <span class="setlist-songbox"><a class="" href="/song/ff" title="FF">FF</a></span> </p>
#  </div>
#  <div class="setlist-footer">
#  <p class="setlist-footnotes"><b>Footnotes</b>:<br/>    [1] debut, original<br/>    [2] debut, original (Stomper Bob)</p>
#  <p><b class="shownotes-label">Show Notes:</b> setlist incomplete</p>
#  </div>
#  </div>
#  </section><section class="setlist-artist-1">
#  <div class="setlist setlist-container">
#  <a class="setlist-anchor" name="setlist-1998-02-11"></a>
#  <div class="setlist-header">
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-february-11-1998-xtreamz-south-bend-in-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-february-11-1998-xtreamz-south-bend-in-usa.html">February 11, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/xtreamz-south-bend-in-usa" target="_top">Xtreamz</a> — <a href="/venues/city/South+Bend/IN" target="_top">South Bend</a>, <a href="/venues/state/IN/USA" target="_top">IN</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>
#  </div>
#  <div class="setlist-body"><br/>
#  <p><b class="setlabel set-1">Set 1:</b> <span class="setlist-songbox"><a class="" href="/song/g-song" title="G-Song">G-Song</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/voulez-vous" title="Voulez-Vous">Voulez-Vous</a><sup title="debut, ABBA">[1]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/bubblehouse" title="Bubblehouse">Bubblehouse</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/g-song" title="G-Song">G-Song</a>, </span> <span class="setlist-songbox"><a class="" href="/song/divisions" title="Divisions">Divisions</a>, </span> <span class="setlist-songbox"><a class="" href="/song/rebubula" title="Rebubula">Rebubula</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/phils-farm" title="Phil's Farm">Phil's Farm</a>, </span> <span class="setlist-songbox"><a class="" href="/song/august" title="August">August</a><sup title="debut, original">[2]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/weekapaug-groove" title="Weekapaug Groove">Weekapaug Groove</a>, </span> <span class="setlist-songbox"><a class="" href="/song/orfeo" title="Orfeo">Orfeo</a>, </span> <span class="setlist-songbox"><a class="" href="/song/cantaloupe-woman" title="Cantaloupe Woman">Cantaloupe Woman</a>, </span> <span class="setlist-songbox"><a class="" href="/song/vibe" title="Vibe">Vibe</a>, </span> <span class="setlist-songbox"><a class="" href="/song/bob" title="Bob">Bob</a><sup title="with Steve Krojniewski on additional percussion">[3]</sup> </span> </p><p><b class="setlabel set-2">Set 2:</b> <span class="setlist-songbox"><a class="" href="/song/muffburger-sandwich" title="Muffburger Sandwich">Muffburger Sandwich</a><sup title="contained a spit flute jam">[4]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/ff" title="FF">FF</a>, </span> <span class="setlist-songbox"><a class="" href="/song/kimble" title="Kimble">Kimble</a>, </span> <span class="setlist-songbox"><a class="" href="/song/gut-strut" title="Gut Strut">Gut Strut</a><sup title="debut, original">[2]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/all-in-time" title="All In Time">All In Time</a>, </span> <span class="setlist-songbox"><a class="" href="/song/burning-down-the-house" title="Burning Down the House">Burning Down the House</a>, </span> <span class="setlist-songbox"><a class="" href="/song/10th-grade" title="10th Grade">10th Grade</a><sup title="with Steve Krojniewski on additional percussion">[3]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/mikes-song" title="Mike's Song">Mike's Song</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/i-am-hydrogen" title="I Am Hydrogen">I Am Hydrogen</a> </span> </p><p><b class="setlabel set-e">Encore:</b> <span class="setlist-songbox"><a class="" href="/song/pour-some-sugar-on-me" title="Pour Some Sugar On Me">Pour Some Sugar On Me</a></span> </p>
#  </div>
#  <div class="setlist-footer">
#  <p class="setlist-footnotes"><b>Footnotes</b>:<br/>    [1] debut, ABBA<br/>    [2] debut, original<br/>    [3] with Steve Krojniewski on additional percussion<br/>    [4] contained a spit flute jam</p>
#  </div>
#  </div>
#  </section><section class="setlist-artist-1">
#  <div class="setlist setlist-container">
#  <a class="setlist-anchor" name="setlist-1998-02-19"></a>
#  <div class="setlist-header">
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-february-19-1998-irish-connection-south-bend-in-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-february-19-1998-irish-connection-south-bend-in-usa.html">February 19, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/irish-connection-south-bend-in-usa" target="_top">Irish Connection</a> — <a href="/venues/city/South+Bend/IN" target="_top">South Bend</a>, <a href="/venues/state/IN/USA" target="_top">IN</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>
#  </div>
#  <div class="setlist-body"><br/>
#  <p><b class="setlabel set-1">Set 1:</b> <span class="setlist-songbox"><a class="" href="/song/vibe" title="Vibe">Vibe</a>, </span> <span class="setlist-songbox"><a class="" href="/song/all-in-time" title="All In Time">All In Time</a>, </span> <span class="setlist-songbox"><a class="" href="/song/burning-down-the-house" title="Burning Down the House">Burning Down the House</a>, </span> <span class="setlist-songbox"><a class="" href="/song/pow" title="Pow">Pow</a><sup title="debut, Beastie Boys">[1]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/groove-holmes" title="Groove Holmes">Groove Holmes</a><sup title="debut, Beastie Boys">[1]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/muffburger-sandwich" title="Muffburger Sandwich">Muffburger Sandwich</a>, </span> <span class="setlist-songbox"><a class="" href="/song/g-song" title="G-Song">G-Song</a>, </span> <span class="setlist-songbox"><a class="" href="/song/phils-farm" title="Phil's Farm">Phil's Farm</a>, </span> <span class="setlist-songbox"><a class="" href="/song/divisions" title="Divisions">Divisions</a>, </span> <span class="setlist-songbox"><a class="" href="/song/rebubula" title="Rebubula">Rebubula</a> </span> </p><p><b class="setlabel set-2">Set 2:</b> <span class="setlist-songbox"><a class="" href="/song/pick-your-nose" title="Pick Your Nose">Pick Your Nose</a><sup title="debut, original">[2]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/gut-strut" title="Gut Strut">Gut Strut</a>, </span> <span class="setlist-songbox"><a class="" href="/song/bob" title="Bob">Bob</a><sup title='with freestyling by Gary "Dope Rhymes" Stanfield and additional rapping from Ryan T.'>[3]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/august" title="August">August</a>, </span> <span class="setlist-songbox">Jamiroquai #7, </span> <span class="setlist-songbox"><a class="" href="/song/kimble" title="Kimble">Kimble</a>, </span> <span class="setlist-songbox"><a class="" href="/song/ff" title="FF">FF</a>, </span> <span class="setlist-songbox"><a class="" href="/song/10th-grade" title="10th Grade">10th Grade</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/take-me-out-to-the-ballgame" title="Take Me Out to the Ballgame">Take Me Out to the Ballgame</a><sup title="debut">[4]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/10th-grade" title="10th Grade">10th Grade</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/run-like-an-antelope" title="Run Like An Antelope">Run Like An Antelope</a><sup title="debut, Phish">[5]</sup> </span> </p><p><b class="setlabel set-e">Encore:</b> <span class="setlist-songbox"><a class="" href="/song/pour-some-sugar-on-me" title="Pour Some Sugar On Me">Pour Some Sugar On Me</a></span> </p>
#  </div>
#  <div class="setlist-footer">
#  <p class="setlist-footnotes"><b>Footnotes</b>:<br/>    [1] debut, Beastie Boys<br/>    [2] debut, original<br/>    [3] with freestyling by Gary "Dope Rhymes" Stanfield and additional rapping from Ryan T.<br/>    [4] debut<br/>    [5] debut, Phish</p>
#  <p><b class="shownotes-label">Show Notes:</b> Take Me Out to the Ballgame was for Harry Caray, who passed away on February 18th</p>
#  </div>
#  </div>
#  </section><section class="setlist-artist-1">
#  <div class="setlist setlist-container">
#  <a class="setlist-anchor" name="setlist-1998-02-20"></a>
#  <div class="setlist-header">
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-february-20-1998-finnigan39s-south-bend-in-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-february-20-1998-finnigan39s-south-bend-in-usa.html">February 20, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/finnigan39s-south-bend-in-usa" target="_top">Finnigan's</a> — <a href="/venues/city/South+Bend/IN" target="_top">South Bend</a>, <a href="/venues/state/IN/USA" target="_top">IN</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>
#  </div>
#  <div class="setlist-body"><br/>
#  <p><b class="setlabel set-1">Set 1:</b> <span class="setlist-songbox">Jam<sup title="with Karl Engelmann on bass">[1]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/10th-grade" title="10th Grade">10th Grade</a><sup title="with Star Wars Main Theme (John Williams) tease from Brendan">[2]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/phils-farm" title="Phil's Farm">Phil's Farm</a>, </span> <span class="setlist-songbox"><a class="" href="/song/august" title="August">August</a>, </span> <span class="setlist-songbox"><a class="" href="/song/salamander-strut" title="Salamander Strut">Salamander Strut</a><sup title="debut, original (Joel Cummins)">[3]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/cantaloupe-woman" title="Cantaloupe Woman">Cantaloupe Woman</a>, </span> <span class="setlist-songbox"><a class="" href="/song/all-in-time" title="All In Time">All In Time</a>, </span> <span class="setlist-songbox"><a class="" href="/song/pow" title="Pow">Pow</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/groove-holmes" title="Groove Holmes">Groove Holmes</a>, </span> <span class="setlist-songbox"><a class="" href="/song/hours" title="Hours">Hours</a><sup title="with Another One Bites the Dust (Queen) tease from Joel">[4]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/kimble" title="Kimble">Kimble</a>, </span> <span class="setlist-songbox"><a class="" href="/song/g-song" title="G-Song">G-Song</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/voulez-vous" title="Voulez-Vous">Voulez-Vous</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/bubblehouse" title="Bubblehouse">Bubblehouse</a><sup title="with various teases">[5]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/g-song" title="G-Song">G-Song</a><sup title="with various teases">[5]</sup> </span> </p><p><b class="setlabel set-2">Set 2:</b> <span class="setlist-songbox"><a class="" href="/song/ff" title="FF">FF</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/jump" title="Jump">Jump</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/ff" title="FF">FF</a>, </span> <span class="setlist-songbox"><a class="" href="/song/pick-your-nose" title="Pick Your Nose">Pick Your Nose</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/drums" title="Drums">Drums</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/pick-your-nose" title="Pick Your Nose">Pick Your Nose</a>, </span> <span class="setlist-songbox"><a class="" href="/song/werewolves-of-london" title="Werewolves of London">Werewolves of London</a><sup title="debut, Warren Zevon; with Lynyrd Skynyrd teases">[6]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/divisions" title="Divisions">Divisions</a>, </span> <span class="setlist-songbox"><a class="" href="/song/orfeo" title="Orfeo">Orfeo</a>, </span> <span class="setlist-songbox"><a class="" href="/song/up-on-cripple-creek" title="Up on Cripple Creek">Up on Cripple Creek</a><sup title="debut, The Band">[7]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/muffburger-sandwich" title="Muffburger Sandwich">Muffburger Sandwich</a>, </span> <span class="setlist-songbox"><a class="" href="/song/vibe" title="Vibe">Vibe</a></span> </p>
#  </div>
#  <div class="setlist-footer">
#  <p class="setlist-footnotes"><b>Footnotes</b>:<br/>    [1] with Karl Engelmann on bass<br/>    [2] with Star Wars Main Theme (John Williams) tease from Brendan<br/>    [3] debut, original (Joel Cummins)<br/>    [4] with Another One Bites the Dust (Queen) tease from Joel<br/>    [5] with various teases<br/>    [6] debut, Warren Zevon; with Lynyrd Skynyrd teases<br/>    [7] debut, The Band</p>
#  <p><b class="shownotes-label">Show Notes:</b> with Tweezer (Phish) tease from Brendan before Salamander Strut</p>
#  </div>
#  </div>
#  </section><section class="setlist-artist-1">
#  <div class="setlist setlist-container">
#  <a class="setlist-anchor" name="setlist-1998-02-27"></a>
#  <div class="setlist-header">
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-february-27-1998-xtreamz-south-bend-in-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-february-27-1998-xtreamz-south-bend-in-usa.html">February 27, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/xtreamz-south-bend-in-usa" target="_top">Xtreamz</a> — <a href="/venues/city/South+Bend/IN" target="_top">South Bend</a>, <a href="/venues/state/IN/USA" target="_top">IN</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>
#  </div>
#  <div class="setlist-body"><br/>
#  <p><b class="setlabel set-1">Set 1:</b> <span class="setlist-songbox"><a class="" href="/song/all-in-time" title="All In Time">All In Time</a>, </span> <span class="setlist-songbox"><a class="" href="/song/g-song" title="G-Song">G-Song</a>, </span> <span class="setlist-songbox"><a class="" href="/song/pow" title="Pow">Pow</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/groove-holmes" title="Groove Holmes">Groove Holmes</a>, </span> <span class="setlist-songbox"><a class="" href="/song/phils-farm" title="Phil's Farm">Phil's Farm</a>, </span> <span class="setlist-songbox"><a class="" href="/song/pick-your-nose" title="Pick Your Nose">Pick Your Nose</a>, </span> <span class="setlist-songbox"><a class="" href="/song/rebubula" title="Rebubula">Rebubula</a>, </span> <span class="setlist-songbox"><a class="" href="/song/cars-trucks-buses" title="Cars Trucks Buses">Cars Trucks Buses</a><sup title="with Keith Syska on saxophone">[1]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/10th-grade" title="10th Grade">10th Grade</a><sup title="with Keith Syska on saxophone">[1]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/vibe" title="Vibe">Vibe</a> </span> </p><p><b class="setlabel set-2">Set 2:</b> <span class="setlist-songbox"><a class="" href="/song/divisions" title="Divisions">Divisions</a>, </span> <span class="setlist-songbox"><a class="" href="/song/ff" title="FF">FF</a>, </span> <span class="setlist-songbox"><a class="" href="/song/up-on-cripple-creek" title="Up on Cripple Creek">Up on Cripple Creek</a><sup title="with Keith Syska on saxophone">[1]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/bob" title="Bob">Bob</a><sup title="with Keith Syska on saxophone">[1]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/gut-strut" title="Gut Strut">Gut Strut</a>, </span> <span class="setlist-songbox"><a class="" href="/song/kimble" title="Kimble">Kimble</a>, </span> <span class="setlist-songbox"><a class="" href="/song/cantaloupe-woman" title="Cantaloupe Woman">Cantaloupe Woman</a><sup title="with Keith Syska on saxophone">[1]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/mikes-song" title="Mike's Song">Mike's Song</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/i-am-hydrogen" title="I Am Hydrogen">I Am Hydrogen</a></span> </p>
#  </div>
#  <div class="setlist-footer">
#  <p class="setlist-footnotes"><b>Footnotes</b>:<br/>    [1] with Keith Syska on saxophone</p>
#  <p><b class="shownotes-label">Show Notes:</b> there was a Tashi Station reunion during set break; Hajimemashite and Funky Bitch were played</p>
#  </div>
#  </div>
#  </section><section class="setlist-artist-1">
#  <div class="setlist setlist-container">
#  <a class="setlist-anchor" name="setlist-1998-02-28"></a>
#  <div class="setlist-header">
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-february-28-1998-madison-oyster-bar-south-bend-in-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-february-28-1998-madison-oyster-bar-south-bend-in-usa.html">February 28, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/madison-oyster-bar-south-bend-in-usa" target="_top">Madison Oyster Bar</a> — <a href="/venues/city/South+Bend/IN" target="_top">South Bend</a>, <a href="/venues/state/IN/USA" target="_top">IN</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>
#  </div>
#  <div class="setlist-body"><br/>
#  <p><b class="setlabel set-1">One Set:</b> <span class="setlist-songbox"><a class="" href="/song/august" title="August">August</a>, </span> <span class="setlist-songbox"><a class="" href="/song/red-baron" title="Red Baron">Red Baron</a>, </span> <span class="setlist-songbox"><a class="" href="/song/ff" title="FF">FF</a>, </span> <span class="setlist-songbox"><a class="" href="/song/phils-farm" title="Phil's Farm">Phil's Farm</a>, </span> <span class="setlist-songbox"><a class="" href="/song/pick-your-nose" title="Pick Your Nose">Pick Your Nose</a>, </span> <span class="setlist-songbox"><a class="" href="/song/10th-grade" title="10th Grade">10th Grade</a><sup title="with Keith Syska on saxophone">[1]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/linus-and-lucy" title="Linus and Lucy">Linus and Lucy</a><sup title="with Keith Syska on saxophone">[1]</sup> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/10th-grade" title="10th Grade">10th Grade</a><sup title="with Keith Syska on saxophone">[1]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/salamander-strut" title="Salamander Strut">Salamander Strut</a>, </span> <span class="setlist-songbox"><a class="" href="/song/strolling-a-suspension-bridge" title="Strolling a Suspension Bridge">Strolling a Suspension Bridge</a><sup title="debut, Seth Kaufman">[2]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/divisions" title="Divisions">Divisions</a>, </span> <span class="setlist-songbox"><a class="" href="/song/cars-trucks-buses" title="Cars Trucks Buses">Cars Trucks Buses</a><sup title="with Keith Syska on saxophone">[1]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/up-on-cripple-creek" title="Up on Cripple Creek">Up on Cripple Creek</a><sup title="with Keith Syska on saxophone">[1]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/hours" title="Hours">Hours</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/kimble" title="Kimble">Kimble</a>, </span> <span class="setlist-songbox"><a class="" href="/song/cantaloupe-woman" title="Cantaloupe Woman">Cantaloupe Woman</a><sup title="with Keith Syska on saxophone">[1]</sup></span> </p>
#  </div>
#  <div class="setlist-footer">
#  <p class="setlist-footnotes"><b>Footnotes</b>:<br/>    [1] with Keith Syska on saxophone<br/>    [2] debut, Seth Kaufman</p>
#  </div>
#  </div>
#  </section><section class="setlist-artist-1">
#  <div class="setlist setlist-container">
#  <a class="setlist-anchor" name="setlist-1998-03-05"></a>
#  <div class="setlist-header">
#  <div class="setlist-date-long">
# ...
#  </div>
#  <div class="setlist-footer">
#  <p class="setlist-footnotes"><b>Footnotes</b>:<br/>    [1] debut, Pink Floyd<br/>    [2] with Divided Sky (Phish) teases<br/>    [3] with "rapfest"</p>
#  </div>
#  </div>,
#  <div class="setlist-header">
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-december-9-1998-the-factory-south-bend-in-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-december-9-1998-the-factory-south-bend-in-usa.html">December 9, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/the-factory-south-bend-in-usa" target="_top">The Factory</a> — <a href="/venues/city/South+Bend/IN" target="_top">South Bend</a>, <a href="/venues/state/IN/USA" target="_top">IN</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>
#  </div>,
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-december-9-1998-the-factory-south-bend-in-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-december-9-1998-the-factory-south-bend-in-usa.html">December 9, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/the-factory-south-bend-in-usa" target="_top">The Factory</a> — <a href="/venues/city/South+Bend/IN" target="_top">South Bend</a>, <a href="/venues/state/IN/USA" target="_top">IN</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>,
#  <div class="setlist-body"><br/>
#  <p><b class="setlabel set-1">Set 1:</b> <span class="setlist-songbox"><a class="" href="/song/divisions" title="Divisions">Divisions</a>, </span> <span class="setlist-songbox"><a class="" href="/song/red-baron" title="Red Baron">Red Baron</a>, </span> <span class="setlist-songbox"><a class="" href="/song/muff-ii-the-revenge" title="Muff II: The Revenge">Muff II: The Revenge</a>, </span> <span class="setlist-songbox"><a class="" href="/song/kimble" title="Kimble">Kimble</a>, </span> <span class="setlist-songbox"><a class="" href="/song/front-porch" title="Front Porch">Front Porch</a>, </span> <span class="setlist-songbox"><a class="" href="/song/2x2" title="2x2">2x2</a>, </span> <span class="setlist-songbox"><a class="" href="/song/salamander-strut" title="Salamander Strut">Salamander Strut</a>, </span> <span class="setlist-songbox"><a class="" href="/song/down-under" title="Down Under">Down Under</a> </span> </p><p><b class="setlabel set-2">Set 2:</b> <span class="setlist-songbox"><a class="" href="/song/g-song" title="G-Song">G-Song</a>, </span> <span class="setlist-songbox"><a class="" href="/song/in-the-flesh" title="In the Flesh?">In the Flesh?</a><sup title="debut, Pink Floyd">[1]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/jessica" title="Jessica">Jessica</a><sup title="with Divided Sky (Phish) teases">[2]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/thin-air" title="Thin Air">Thin Air</a>, </span> <span class="setlist-songbox"><a class="" href="/song/all-in-time" title="All In Time">All In Time</a>, </span> <span class="setlist-songbox"><a class="" href="/song/help-on-the-way" title="Help On the Way">Help On the Way</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/slipknot" title="Slipknot!">Slipknot!</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/celtic-alleluia" title="Celtic Alleluia">Celtic Alleluia</a>, </span> <span class="setlist-songbox"><a class="" href="/song/nachos-for-two" title="Nachos for Two">Nachos for Two</a>, </span> <span class="setlist-songbox"><a class="" href="/song/der-bluten-kat" title="Der Bluten Kat">Der Bluten Kat</a>, </span> <span class="setlist-songbox"><a class="" href="/song/hangover" title="Hangover">Hangover</a>, </span> <span class="setlist-songbox"><a class="" href="/song/phils-farm" title="Phil's Farm">Phil's Farm</a>, </span> <span class="setlist-songbox"><a class="" href="/song/ff" title="FF">FF</a>, </span> <span class="setlist-songbox"><a class="" href="/song/patience" title="Patience">Patience</a>, </span> <span class="setlist-songbox"><a class="" href="/song/pow" title="Pow">Pow</a><sup title='with "rapfest"'>[3]</sup>, </span> <span class="setlist-songbox"><a class="" href="/song/bob" title="Bob">Bob</a></span> </p>
#  </div>,
#  <div class="setlist-footer">
#  <p class="setlist-footnotes"><b>Footnotes</b>:<br/>    [1] debut, Pink Floyd<br/>    [2] with Divided Sky (Phish) teases<br/>    [3] with "rapfest"</p>
#  </div>,
#  <div class="setlist setlist-container">
#  <a class="setlist-anchor" name="setlist-1998-12-11"></a>
#  <div class="setlist-header">
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-december-11-1998-martyrs039-chicago-il-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-december-11-1998-martyrs039-chicago-il-usa.html">December 11, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/martyrs039-chicago-il-usa" target="_top">Martyrs'</a> — <a href="/venues/city/Chicago/IL" target="_top">Chicago</a>, <a href="/venues/state/IL/USA" target="_top">IL</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>
#  </div>
#  <div class="setlist-body"><br/>
#  <p><b class="setlabel set-1">One Set:</b> <span class="setlist-songbox"><a class="" href="/song/red-baron" title="Red Baron">Red Baron</a>, </span> <span class="setlist-songbox"><a class="" href="/song/all-in-time" title="All In Time">All In Time</a>, </span> <span class="setlist-songbox"><a class="" href="/song/down-under" title="Down Under">Down Under</a>, </span> <span class="setlist-songbox"><a class="" href="/song/g-song" title="G-Song">G-Song</a>, </span> <span class="setlist-songbox"><a class="" href="/song/front-porch" title="Front Porch">Front Porch</a>, </span> <span class="setlist-songbox"><a class="" href="/song/kimble" title="Kimble">Kimble</a>, </span> <span class="setlist-songbox"><a class="" href="/song/muff-ii-the-revenge" title="Muff II: The Revenge">Muff II: The Revenge</a>, </span> <span class="setlist-songbox"><a class="" href="/song/2x2" title="2x2">2x2</a>, </span> <span class="setlist-songbox"><a class="" href="/song/the-other-side-of-things" title="The Other Side of Things">The Other Side of Things</a>, </span> <span class="setlist-songbox"><a class="" href="/song/hangover" title="Hangover">Hangover</a>, </span> <span class="setlist-songbox"><a class="" href="/song/thin-air" title="Thin Air">Thin Air</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/lively-up-yourself" title="Lively Up Yourself">Lively Up Yourself</a>, </span> <span class="setlist-songbox"><a class="" href="/song/der-bluten-kat" title="Der Bluten Kat">Der Bluten Kat</a>, </span> <span class="setlist-songbox"><a class="" href="/song/much-obliged" title="Much Obliged">Much Obliged</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/hajimemashite" title="Hajimemashite">Hajimemashite</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/much-obliged" title="Much Obliged">Much Obliged</a>, </span> <span class="setlist-songbox"><a class="" href="/song/ff" title="FF">FF</a></span> </p>
#  </div>
#  <div class="setlist-footer">
#  </div>
#  </div>,
#  <div class="setlist-header">
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-december-11-1998-martyrs039-chicago-il-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-december-11-1998-martyrs039-chicago-il-usa.html">December 11, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/martyrs039-chicago-il-usa" target="_top">Martyrs'</a> — <a href="/venues/city/Chicago/IL" target="_top">Chicago</a>, <a href="/venues/state/IL/USA" target="_top">IL</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>
#  </div>,
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-december-11-1998-martyrs039-chicago-il-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-december-11-1998-martyrs039-chicago-il-usa.html">December 11, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/martyrs039-chicago-il-usa" target="_top">Martyrs'</a> — <a href="/venues/city/Chicago/IL" target="_top">Chicago</a>, <a href="/venues/state/IL/USA" target="_top">IL</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>,
#  <div class="setlist-body"><br/>
#  <p><b class="setlabel set-1">One Set:</b> <span class="setlist-songbox"><a class="" href="/song/red-baron" title="Red Baron">Red Baron</a>, </span> <span class="setlist-songbox"><a class="" href="/song/all-in-time" title="All In Time">All In Time</a>, </span> <span class="setlist-songbox"><a class="" href="/song/down-under" title="Down Under">Down Under</a>, </span> <span class="setlist-songbox"><a class="" href="/song/g-song" title="G-Song">G-Song</a>, </span> <span class="setlist-songbox"><a class="" href="/song/front-porch" title="Front Porch">Front Porch</a>, </span> <span class="setlist-songbox"><a class="" href="/song/kimble" title="Kimble">Kimble</a>, </span> <span class="setlist-songbox"><a class="" href="/song/muff-ii-the-revenge" title="Muff II: The Revenge">Muff II: The Revenge</a>, </span> <span class="setlist-songbox"><a class="" href="/song/2x2" title="2x2">2x2</a>, </span> <span class="setlist-songbox"><a class="" href="/song/the-other-side-of-things" title="The Other Side of Things">The Other Side of Things</a>, </span> <span class="setlist-songbox"><a class="" href="/song/hangover" title="Hangover">Hangover</a>, </span> <span class="setlist-songbox"><a class="" href="/song/thin-air" title="Thin Air">Thin Air</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/lively-up-yourself" title="Lively Up Yourself">Lively Up Yourself</a>, </span> <span class="setlist-songbox"><a class="" href="/song/der-bluten-kat" title="Der Bluten Kat">Der Bluten Kat</a>, </span> <span class="setlist-songbox"><a class="" href="/song/much-obliged" title="Much Obliged">Much Obliged</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/hajimemashite" title="Hajimemashite">Hajimemashite</a> &gt; </span> <span class="setlist-songbox"><a class="" href="/song/much-obliged" title="Much Obliged">Much Obliged</a>, </span> <span class="setlist-songbox"><a class="" href="/song/ff" title="FF">FF</a></span> </p>
#  </div>,
#  <div class="setlist-footer">
#  </div>,
#  <div class="setlist setlist-container">
#  <a class="setlist-anchor" name="setlist-1998-12-17"></a>
#  <div class="setlist-header">
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-december-17-1998-the-factory-south-bend-in-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-december-17-1998-the-factory-south-bend-in-usa.html">December 17, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/the-factory-south-bend-in-usa" target="_top">The Factory</a> — <a href="/venues/city/South+Bend/IN" target="_top">South Bend</a>, <a href="/venues/state/IN/USA" target="_top">IN</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>
#  </div>
#  <div class="setlist-body"><br/>
#  <p>No known setlist</p>
#  </div>
#  <div class="setlist-footer">
#  </div>
#  </div>,
#  <div class="setlist-header">
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-december-17-1998-the-factory-south-bend-in-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-december-17-1998-the-factory-south-bend-in-usa.html">December 17, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/the-factory-south-bend-in-usa" target="_top">The Factory</a> — <a href="/venues/city/South+Bend/IN" target="_top">South Bend</a>, <a href="/venues/state/IN/USA" target="_top">IN</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>
#  </div>,
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-december-17-1998-the-factory-south-bend-in-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-december-17-1998-the-factory-south-bend-in-usa.html">December 17, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/the-factory-south-bend-in-usa" target="_top">The Factory</a> — <a href="/venues/city/South+Bend/IN" target="_top">South Bend</a>, <a href="/venues/state/IN/USA" target="_top">IN</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>,
#  <div class="setlist-body"><br/>
#  <p>No known setlist</p>
#  </div>,
#  <div class="setlist-footer">
#  </div>,
#  <div class="setlist setlist-container">
#  <a class="setlist-anchor" name="setlist-1998-12-18"></a>
#  <div class="setlist-header">
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-december-18-1998-madison-oyster-bar-south-bend-in-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-december-18-1998-madison-oyster-bar-south-bend-in-usa.html">December 18, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/madison-oyster-bar-south-bend-in-usa" target="_top">Madison Oyster Bar</a> — <a href="/venues/city/South+Bend/IN" target="_top">South Bend</a>, <a href="/venues/state/IN/USA" target="_top">IN</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>
#  </div>
#  <div class="setlist-body"><br/>
#  <p>No known setlist</p>
#  </div>
#  <div class="setlist-footer">
#  </div>
#  </div>,
#  <div class="setlist-header">
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-december-18-1998-madison-oyster-bar-south-bend-in-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-december-18-1998-madison-oyster-bar-south-bend-in-usa.html">December 18, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/madison-oyster-bar-south-bend-in-usa" target="_top">Madison Oyster Bar</a> — <a href="/venues/city/South+Bend/IN" target="_top">South Bend</a>, <a href="/venues/state/IN/USA" target="_top">IN</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>
#  </div>,
#  <div class="setlist-date-long">
#  <span class="setlist-date">
#  <a href="/setlists/umphreys-mcgee-december-18-1998-madison-oyster-bar-south-bend-in-usa.html"><i class="fa fa-link" style="color:#888;font-size:60%"></i></a> <a href="/setlists/umphreys-mcgee-december-18-1998-madison-oyster-bar-south-bend-in-usa.html">December 18, 1998</a>
#  <a href="/setlists/umphreys-mcgee" style="">Umphrey's McGee</a> —
#  				<a class="venue" href="/venues/madison-oyster-bar-south-bend-in-usa" target="_top">Madison Oyster Bar</a> — <a href="/venues/city/South+Bend/IN" target="_top">South Bend</a>, <a href="/venues/state/IN/USA" target="_top">IN</a>, <a href="/venues/country/USA" target="_top">USA</a>
#  </span></div>,
#  <div class="setlist-body"><br/>
#  <p>No known setlist</p>
#  </div>,
#  <div class="setlist-footer">
#  </div>]
